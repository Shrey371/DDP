# %%
# import os
import pandas as pd
# import cv2
# import matplotlib.pyplot as plt
# import numpy as np
# import math
# import tensorflow as tf
import pycaret

# %matplotlib inline

# %%
print('PyCaret: %s' % pycaret.__version__)
# Out:
# PyCaret: 3.1.0

# %%
train=pd.read_csv('training.csv')
test=pd.read_csv('testing.csv')
data=pd.read_csv('total_data.csv')

# %%
test.head()
# Out:
#    number  gender   age      mean_r      mean_g      mean_b    mean_rg  \
# 0       4     1.0  39.0  168.003551  142.526411  171.719288  41.573798
# 1       5     1.0  29.0  161.395007  128.240333  153.480755  58.491050
# 2       8     0.0  32.0  171.092908  112.428535  139.891132  77.786821
# 3       9     0.0  32.0  159.498131   90.163154  131.569181  69.875430
# 4      24     1.0  23.0  148.109619  114.570254  139.216847  65.133211
#
#         HHR          Ent           B        G1        G2            G3  \
# 0  0.007344  1248.653137  153.478341  3.447792  3.346256  6.161600e-02
# 1  0.031040   873.921511  141.151901  3.134768  2.984544  7.098667e-02
# 2  0.104768  1146.306784  132.693683  3.844800  3.963088  4.575467e-02
# 3  0.032320   654.198938  115.642262  2.347872  2.530512  3.765333e-02
# 4  0.052416  1220.238916  127.424177  3.555808  3.648384  2.090000e-17
#
#          G4         G5  label   hgb
# 0  2.564352  49.143024      1   8.3
# 1  2.302943  41.525760      1   7.8
# ...

# %%
data.shape
# Out:
# (95, 18)

# %%
data.drop('gender_actual',axis=1,inplace=True)
data.head()
# Out:
#    number  gender  age      mean_r      mean_g      mean_b    mean_rg  \
# 0       1       0   29  162.253551  110.344051  140.106420  66.783275
# 1       2       1   36   93.155839   57.903152   82.817630  46.735631
# 2       3       1   30  156.337977  127.740262  153.386077  54.392947
# 3       4       1   39  168.003551  142.526411  171.719288  41.573798
# 4       5       1   29  161.395007  128.240333  153.480755  58.491050
#
#         HHR          Ent           B        G1        G2            G3  \
# 0  0.051072  1125.472761  129.062154  3.390000  3.542816 -6.590000e-18
# 1  0.024032   564.048278   68.833649  1.175424  1.272608  1.460000e-17
# 2  0.017872   695.100841  139.239840  2.593296  2.793504 -8.640000e-18
# 3  0.007344  1248.653137  153.478341  3.447792  3.346256  6.161600e-02
# 4  0.031040   873.921511  141.151901  3.134768  2.984544  7.098667e-02
#
#          G4         G5  label   hgb
# 0  2.562056  40.268672      0  12.2
# 1  0.917702   8.827232      1   8.0
# ...

# %% [markdown]
# # Classification

# %%
from pycaret.classification import *
s = setup(data, target='label', ignore_features=['hgb','number','mean_b','mean_rg','B','G2','G4','G5'], preprocess=False, session_id=123)
# Out:
# <style type="text/css">
# </style>
# <table id="T_33702">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_33702_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_33702_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_33702_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_33702_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_33702_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_33702_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_33702_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_33702_row1_col1" class="data row1 col1" >label</td>
#     </tr>
#     <tr>
#       <th id="T_33702_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_33702_row2_col0" class="data row2 col0" >Target type</td>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_bfc4f th {
#   text-align: left;
# }
# ...

# %%
print(best)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=123, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_11736">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_11736_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_11736_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_11736_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_11736_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_11736_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_11736_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_11736_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_11736_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11736_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_11736_row0_col0" class="data row0 col0" >Logistic Regression</td>
# ...

# %%
# predict_model(best,data=test.drop(['hgb','number'],axis=1))

# %%
# predict_model(best,data=train.drop(['hgb','number'],axis=1))

# %% [markdown]
# # Regression

# %%
from pycaret.regression import *
s = setup(data, target='hgb', ignore_features=['label','number','mean_b','mean_rg','B','G2','G4','G5'], preprocess=False, session_id=123)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ca4d7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ca4d7_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ca4d7_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ca4d7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ca4d7_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_ca4d7_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_ca4d7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ca4d7_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_ca4d7_row1_col1" class="data row1 col1" >hgb</td>
#     </tr>
#     <tr>
#       <th id="T_ca4d7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ca4d7_row2_col0" class="data row2 col0" >Target type</td>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_5fb7e th {
#   text-align: left;
# }
# ...

# %%
print(best)

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_833ec">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_833ec_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_833ec_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_833ec_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_833ec_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_833ec_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_833ec_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_833ec_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_833ec_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_833ec_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_833ec_row0_col1" class="data row0 col1" >1.1583</td>
# ...

# %%
# predict_model(best,data=test.drop(['label','number'],axis=1))

# %%
# predict_model(best,data=train.drop(['label','number'],axis=1))

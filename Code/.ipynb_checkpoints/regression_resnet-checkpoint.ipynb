# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
from PIL import Image, ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True
import torch
import torch.nn as nn
import torchvision.models as models
import torchvision.transforms as transforms
# from torchvision import transforms
import os
import glob
import torch

# %%
df = pd.read_excel("../India_95/India.xlsx",0)

# %%
df.head()
# Out:
#    Number   Hgb  Gender  Age
# 0       1  12.2       0   29
# 1       2   8.0       1   36
# 2       3  10.7       1   30
# 3       4   8.3       1   39
# 4       5   7.8       1   29

# %%
from torchvision.models import resnet18, ResNet18_Weights

resnet = resnet18(weights=ResNet18_Weights.DEFAULT)
# or any of these variants
# from torchvision.models import resnet34, ResNet34_Weights
# from torchvision.models import resnet50, ResNet50_Weights
# from torchvision.models import resnet101, ResNet101_Weights
# from torchvision.models import resnet152, ResNet152_Weights

modules = list(resnet.children())[:-1]
resnet = nn.Sequential(*modules)

resnet.eval()

def preprocess_image(filename):
    input_image = Image.open(filename)

    # input_image.load()
    # background = Image.new("RGB", input_image.size, (255, 255, 255))
    # background.paste(input_image, mask = input_image.split()[3])

    background = input_image.convert('RGB')

    preprocess = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])

    return preprocess(background).unsqueeze(0)

# %%
training = "../India_95/training"
testing = "../India_95/testing"
all_data = "../India_95/All"


training_img = glob.glob(f"{training}/*.png")
testing_img = glob.glob(f"{testing}/*.png")
all_img = sorted(glob.glob(f"{all_data}/*.png"))

# %%
All_Data = []
errors = []

for i in all_img:

    number = i.split("/")[-1].split(".")[0]
    label = df.loc[df['Number'] == int(number)]['Hgb'].tolist()[0]

    try:
        input_batch = preprocess_image(i)

        if torch.cuda.is_available():
            input_batch = input_batch.to('cuda')
            resnet.to('cuda')

        with torch.no_grad():
            output = resnet(input_batch)

        # data = [number,label]
        output = output.cpu()
        data = output.squeeze().numpy()
        data = data.flatten().tolist()

        data.insert(0,number)
        data.append(label)

        All_Data.append(data)

    except Exception as e:
        error = [number,e]
        errors.append(error)

# %%
headers = ['number']
for i in range(512):
    col = 'data_' + str(i)
    headers.append(col)
headers.append('label')
df_save = pd.DataFrame(All_Data, columns=headers)
df_save.to_csv('../India_95/Data.csv', index=False)

# %%
header2 = ['number','error_message']
df_error = pd.DataFrame(errors, columns=header2)
df_error.to_csv('../India_95/Error_files.csv', index=False)

# %%
len(All_Data)
# Out:
# 95

# %%
len(errors)
# Out:
# 0

# %%
import pycaret

# %%
data = pd.read_csv('../India_95/Data.csv')

# %%
data.head()
# Out:
#    number    data_0    data_1    data_2    data_3    data_4    data_5  \
# 0       1  1.899122  0.722537  0.026443  1.817490  1.046539  0.164434
# 1      10  1.640895  0.398874  0.050168  1.135315  0.156090  0.922679
# 2      11  0.552463  0.125926  0.073117  0.854506  0.248553  1.054864
# 3      12  0.669462  0.181472  0.009806  2.037710  0.748018  0.613822
# 4      13  1.496742  0.412638  0.017743  1.570459  0.495749  0.676278
#
#      data_6    data_7    data_8  ...  data_503  data_504  data_505  data_506  \
# 75%     1.065249  12.800000
# max     3.227088  17.100000
#
# [8 rows x 514 columns]

# %%
from pycaret.regression import *
s = setup(data, target='label', ignore_features=['number'], 
          #log_experiment=True, experiment_name="resnet_2", log_data=True, 
          #pca=True, pca_method="linear", 
          remove_multicollinearity=True, multicollinearity_threshold=0.5,
          preprocess=True, 
          normalize=True, 
          session_id=123)
#feature_selection=True, feature_selection_method="sequential", n_features_to_select=0.02,
# Out:
# <style type="text/css">
# #T_0faee_row9_col1, #T_0faee_row13_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_0faee">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0faee_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_0faee_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0faee_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0faee_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_0faee_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_0faee_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0faee_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_0faee_row1_col1" class="data row1 col1" >label</td>
#     </tr>
#     <tr>
#       <th id="T_0faee_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0faee_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_0faee_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_0faee_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0faee_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_0faee_row3_col1" class="data row3 col1" >(95, 514)</td>
#     </tr>
#     <tr>
#       <th id="T_0faee_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0faee_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_0faee_row4_col1" class="data row4 col1" >(95, 513)</td>
#     </tr>
#     <tr>
#       <th id="T_0faee_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0faee_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_0faee_row5_col1" class="data row5 col1" >(66, 513)</td>
#     </tr>
#     <tr>
#       <th id="T_0faee_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0faee_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_0faee_row6_col1" class="data row6 col1" >(29, 513)</td>
#     </tr>
#     <tr>
#       <th id="T_0faee_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0faee_row7_col0" class="data row7 col0" >Ignore features</td>
#       <td id="T_0faee_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_0faee_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0faee_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_0faee_row8_col1" class="data row8 col1" >512</td>
#     </tr>
#     <tr>
#       <th id="T_0faee_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0faee_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_0faee_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_0faee_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_0faee_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_0faee_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_0faee_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_0faee_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_0faee_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_0faee_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_0faee_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_0faee_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_0faee_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_0faee_row13_col0" class="data row13 col0" >Normalize</td>
#       <td id="T_0faee_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_0faee_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_0faee_row14_col0" class="data row14 col0" >Normalize method</td>
#       <td id="T_0faee_row14_col1" class="data row14 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_0faee_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_0faee_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_0faee_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_0faee_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_0faee_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_0faee_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_0faee_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_0faee_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_0faee_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_0faee_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_0faee_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_0faee_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_0faee_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_0faee_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_0faee_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_0faee_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_0faee_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_0faee_row20_col1" class="data row20 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_0faee_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_0faee_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_0faee_row21_col1" class="data row21 col1" >aa6c</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_r = compare_models(sort="RMSE")
# Out:
# <style type="text/css">
# #T_d677d th {
#   text-align: left;
# }
# #T_d677d_row0_col0, #T_d677d_row0_col4, #T_d677d_row1_col0, #T_d677d_row1_col1, #T_d677d_row1_col2, #T_d677d_row1_col3, #T_d677d_row1_col5, #T_d677d_row1_col6, #T_d677d_row2_col0, #T_d677d_row2_col1, #T_d677d_row2_col2, #T_d677d_row2_col3, #T_d677d_row2_col5, #T_d677d_row2_col6, #T_d677d_row3_col0, #T_d677d_row3_col1, #T_d677d_row3_col2, #T_d677d_row3_col3, #T_d677d_row3_col5, #T_d677d_row3_col6, #T_d677d_row4_col0, #T_d677d_row4_col1, #T_d677d_row4_col2, #T_d677d_row4_col3, #T_d677d_row4_col4, #T_d677d_row4_col5, #T_d677d_row4_col6, #T_d677d_row5_col0, #T_d677d_row5_col1, #T_d677d_row5_col2, #T_d677d_row5_col3, #T_d677d_row5_col4, #T_d677d_row5_col5, #T_d677d_row5_col6, #T_d677d_row6_col0, #T_d677d_row6_col1, #T_d677d_row6_col2, #T_d677d_row6_col3, #T_d677d_row6_col4, #T_d677d_row6_col5, #T_d677d_row6_col6, #T_d677d_row7_col0, #T_d677d_row7_col1, #T_d677d_row7_col2, #T_d677d_row7_col3, #T_d677d_row7_col4, #T_d677d_row7_col5, #T_d677d_row7_col6, #T_d677d_row8_col0, #T_d677d_row8_col1, #T_d677d_row8_col2, #T_d677d_row8_col3, #T_d677d_row8_col4, #T_d677d_row8_col5, #T_d677d_row8_col6, #T_d677d_row9_col0, #T_d677d_row9_col1, #T_d677d_row9_col2, #T_d677d_row9_col3, #T_d677d_row9_col4, #T_d677d_row9_col5, #T_d677d_row9_col6, #T_d677d_row10_col0, #T_d677d_row10_col1, #T_d677d_row10_col2, #T_d677d_row10_col3, #T_d677d_row10_col4, #T_d677d_row10_col5, #T_d677d_row10_col6, #T_d677d_row11_col0, #T_d677d_row11_col1, #T_d677d_row11_col2, #T_d677d_row11_col3, #T_d677d_row11_col4, #T_d677d_row11_col5, #T_d677d_row11_col6, #T_d677d_row12_col0, #T_d677d_row12_col1, #T_d677d_row12_col2, #T_d677d_row12_col3, #T_d677d_row12_col4, #T_d677d_row12_col5, #T_d677d_row12_col6, #T_d677d_row13_col0, #T_d677d_row13_col1, #T_d677d_row13_col2, #T_d677d_row13_col3, #T_d677d_row13_col4, #T_d677d_row13_col5, #T_d677d_row13_col6, #T_d677d_row14_col0, #T_d677d_row14_col1, #T_d677d_row14_col2, #T_d677d_row14_col3, #T_d677d_row14_col4, #T_d677d_row14_col5, #T_d677d_row14_col6, #T_d677d_row15_col0, #T_d677d_row15_col1, #T_d677d_row15_col2, #T_d677d_row15_col3, #T_d677d_row15_col4, #T_d677d_row15_col5, #T_d677d_row15_col6, #T_d677d_row16_col0, #T_d677d_row16_col1, #T_d677d_row16_col2, #T_d677d_row16_col3, #T_d677d_row16_col4, #T_d677d_row16_col5, #T_d677d_row16_col6, #T_d677d_row17_col0, #T_d677d_row17_col1, #T_d677d_row17_col2, #T_d677d_row17_col3, #T_d677d_row17_col4, #T_d677d_row17_col5, #T_d677d_row17_col6 {
#   text-align: left;
# }
# #T_d677d_row0_col1, #T_d677d_row0_col2, #T_d677d_row0_col3, #T_d677d_row0_col5, #T_d677d_row0_col6, #T_d677d_row1_col4, #T_d677d_row2_col4, #T_d677d_row3_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_d677d_row0_col7, #T_d677d_row1_col7, #T_d677d_row2_col7, #T_d677d_row3_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_d677d_row4_col7, #T_d677d_row5_col7, #T_d677d_row6_col7, #T_d677d_row7_col7, #T_d677d_row8_col7, #T_d677d_row9_col7, #T_d677d_row10_col7, #T_d677d_row11_col7, #T_d677d_row12_col7, #T_d677d_row13_col7, #T_d677d_row14_col7, #T_d677d_row15_col7, #T_d677d_row16_col7, #T_d677d_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_d677d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d677d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d677d_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_d677d_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_d677d_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_d677d_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_d677d_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_d677d_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_d677d_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d677d_level0_row0" class="row_heading level0 row0" >knn</th>
#       <td id="T_d677d_row0_col0" class="data row0 col0" >K Neighbors Regressor</td>
#       <td id="T_d677d_row0_col1" class="data row0 col1" >1.6863</td>
#       <td id="T_d677d_row0_col2" class="data row0 col2" >4.2850</td>
#       <td id="T_d677d_row0_col3" class="data row0 col3" >2.0168</td>
#       <td id="T_d677d_row0_col4" class="data row0 col4" >-0.2171</td>
#       <td id="T_d677d_row0_col5" class="data row0 col5" >0.1655</td>
#       <td id="T_d677d_row0_col6" class="data row0 col6" >0.1523</td>
#       <td id="T_d677d_row0_col7" class="data row0 col7" >0.0050</td>
#     </tr>
#     <tr>
#       <th id="T_
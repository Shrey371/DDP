# %%
import os
import pandas as pd
import cv2
import matplotlib.pyplot as plt
import numpy as np
import math
import tensorflow as tf

# %matplotlib inline

# %%
actual = pd.read_excel('../India_95/India.xlsx',0)

# %%
actual.head(5)
# Out:
#    Number   Hgb  Gender  Age
# 0       1  12.2       0   29
# 1       2   8.0       1   36
# 2       3  10.7       1   30
# 3       4   8.3       1   39
# 4       5   7.8       1   29

# %%
testing = pd.read_csv('testing.csv')
training = pd.read_csv('training.csv')

# %%
testing.columns.values
# Out:
# array(['number', 'mean_r', 'mean_g', 'mean_b', 'mean_rg', 'HHR', 'Ent',
#        'B', 'G1', 'G2', 'G3', 'G4', 'G5', 'label'], dtype=object)

# %%
# new_col = 'number' 
# testing_name = testing['name'].tolist()
# testing_number = [i.split('.')[0] for i in testing_name]

# %%
# training_name = training['name'].tolist()
# training_number = [i.split('.')[0] for i in training_name]

# %%
# testing.insert(1,new_col,testing_number)
# training.insert(1,new_col,training_number)

# %%
# training.to_csv('training.csv')
# testing.to_csv('testing.csv')

# %%
testing.head(5)
# Out:
#    number      mean_r      mean_g      mean_b    mean_rg       HHR  \
# 0       4  168.003551  142.526411  171.719288  41.573798  0.007344
# 1       5  161.395007  128.240333  153.480755  58.491050  0.031040
# 2       8  171.092908  112.428535  139.891132  77.786821  0.104768
# 3       9  159.498131   90.163154  131.569181  69.875430  0.032320
# 4      24  148.109619  114.570254  139.216847  65.133211  0.052416
#
#            Ent           B        G1        G2            G3        G4  \
# 0  1248.653137  153.478341  3.447792  3.346256  6.161600e-02  2.564352
# 1   873.921511  141.151901  3.134768  2.984544  7.098667e-02  2.302943
# 2  1146.306784  132.693683  3.844800  3.963088  4.575467e-02  2.932350
# 3   654.198938  115.642262  2.347872  2.530512  3.765333e-02  1.780206
# 4  1220.238916  127.424177  3.555808  3.648384  2.090000e-17  2.645822
#
#           G5  label
# 0  49.143024      1
# 1  41.525760      1
# 2  42.328048      0
# 3  17.336144      0
# 4  41.912336      0

# %%
training.head(5)
# Out:
#    number      mean_r      mean_g      mean_b    mean_rg       HHR  \
# 0       1  162.253551  110.344051  140.106420  66.783275  0.051072
# 1       2   93.155839   57.903152   82.817630  46.735631  0.024032
# 2       3  156.337977  127.740262  153.386077  54.392947  0.017872
# 3       6  141.360025  103.354281  134.519025  49.132086  0.045600
# 4       7  156.915531  112.062968  143.527488  53.952660  0.042544
#
#            Ent           B        G1        G2            G3        G4  \
# 0  1125.472761  129.062154  3.390000  3.542816 -6.590000e-18  2.562056
# 1   564.048278   68.833649  1.175424  1.272608  1.460000e-17  0.917702
# 2   695.100841  139.239840  2.593296  2.793504 -8.640000e-18  2.032372
# 3   844.874884  118.273031  3.275696  3.322160  3.722667e-02  2.381599
# 4   937.325162  129.061496  2.918240  3.164400  7.190000e-17  2.279173
#
#           G5  label
# 0  40.268672      0
# 1   8.827232      1
# 2  28.944064      1
# 3  32.837504      0
# 4  32.298512      1

# %%
actual.columns.values
# Out:
# array(['Number', 'Hgb', 'Gender', 'Age'], dtype=object)

# %%
actual_list = actual.values.tolist()

# %%
actual_list[0]
# Out:
# [1.0, 12.2, 0.0, 29.0]

# %%
len(actual_list[0])
# Out:
# 4

# %%
testing_number = testing['number'].tolist()
training_number = training['number'].tolist()

# %%
hgb_test = [i[1] for i in actual_list if i[0] in testing_number]
gender_test = [i[2] for i in actual_list if i[0] in testing_number]
age_test = [i[3] for i in actual_list if i[0] in testing_number]

# %%
hgb_train = [i[1] for i in actual_list if i[0] in training_number]
gender_train = [i[2] for i in actual_list if i[0] in training_number]
age_train = [i[3] for i in actual_list if i[0] in training_number]

# %%
training['hgb']=hgb_train
testing['hgb']=hgb_test

# %%
training.head(5)
# Out:
#    number      mean_r      mean_g      mean_b    mean_rg       HHR  \
# 0       1  162.253551  110.344051  140.106420  66.783275  0.051072
# 1       2   93.155839   57.903152   82.817630  46.735631  0.024032
# 2       3  156.337977  127.740262  153.386077  54.392947  0.017872
# 3       6  141.360025  103.354281  134.519025  49.132086  0.045600
# 4       7  156.915531  112.062968  143.527488  53.952660  0.042544
#
#            Ent           B        G1        G2            G3        G4  \
# 0  1125.472761  129.062154  3.390000  3.542816 -6.590000e-18  2.562056
# 1   564.048278   68.833649  1.175424  1.272608  1.460000e-17  0.917702
# 2   695.100841  139.239840  2.593296  2.793504 -8.640000e-18  2.032372
# 3   844.874884  118.273031  3.275696  3.322160  3.722667e-02  2.381599
# 4   937.325162  129.061496  2.918240  3.164400  7.190000e-17  2.279173
#
#           G5  label   hgb
# 0  40.268672      0  12.2
# 1   8.827232      1   8.0
# 2  28.944064      1  10.7
# ...

# %%
training.insert(1,'gender',gender_train)
training.insert(2,'age',age_train)
training.head(5)
# Out:
#    number  gender   age      mean_r      mean_g      mean_b    mean_rg  \
# 0       1     0.0  29.0  162.253551  110.344051  140.106420  66.783275
# 1       2     1.0  36.0   93.155839   57.903152   82.817630  46.735631
# 2       3     1.0  30.0  156.337977  127.740262  153.386077  54.392947
# 3       6     1.0  55.0  141.360025  103.354281  134.519025  49.132086
# 4       7     1.0  27.0  156.915531  112.062968  143.527488  53.952660
#
#         HHR          Ent           B        G1        G2            G3  \
# 0  0.051072  1125.472761  129.062154  3.390000  3.542816 -6.590000e-18
# 1  0.024032   564.048278   68.833649  1.175424  1.272608  1.460000e-17
# 2  0.017872   695.100841  139.239840  2.593296  2.793504 -8.640000e-18
# 3  0.045600   844.874884  118.273031  3.275696  3.322160  3.722667e-02
# 4  0.042544   937.325162  129.061496  2.918240  3.164400  7.190000e-17
#
#          G4         G5  label   hgb
# 0  2.562056  40.268672      0  12.2
# 1  0.917702   8.827232      1   8.0
# ...

# %%
testing.insert(1,'gender',gender_test)
testing.insert(2,'age',age_test)
testing.head(5)
# Out:
#    number  gender   age      mean_r      mean_g      mean_b    mean_rg  \
# 0       4     1.0  39.0  168.003551  142.526411  171.719288  41.573798
# 1       5     1.0  29.0  161.395007  128.240333  153.480755  58.491050
# 2       8     0.0  32.0  171.092908  112.428535  139.891132  77.786821
# 3       9     0.0  32.0  159.498131   90.163154  131.569181  69.875430
# 4      24     1.0  23.0  148.109619  114.570254  139.216847  65.133211
#
#         HHR          Ent           B        G1        G2            G3  \
# 0  0.007344  1248.653137  153.478341  3.447792  3.346256  6.161600e-02
# 1  0.031040   873.921511  141.151901  3.134768  2.984544  7.098667e-02
# 2  0.104768  1146.306784  132.693683  3.844800  3.963088  4.575467e-02
# 3  0.032320   654.198938  115.642262  2.347872  2.530512  3.765333e-02
# 4  0.052416  1220.238916  127.424177  3.555808  3.648384  2.090000e-17
#
#          G4         G5  label   hgb
# 0  2.564352  49.143024      1   8.3
# 1  2.302943  41.525760      1   7.8
# ...

# %%
# training.drop(columns='name',inplace=True)
# testing.drop(columns='name',inplace=True)

# %%
training.to_csv('training.csv',index=False)
testing.to_csv('testing.csv',index=False)
